# %%
import pandas as pd
df_data = pd.read_csv(r"/home/devesh/Documents/edwisor_assignment/data.csv", encoding = "unicode_escape", skiprows = [2], thousands=',')

# %%
df_data
# Out:
#                                                    Plot  \
# 0     Despite his tarnished reputation after the eve...
# 1     Based on the novel written by Stephen Chbosky,...
# 2     Mike Lane is a thirty-year old living in Tampa...
# 3     When Bond's latest assignment goes gravely wro...
# 4     Against medical advice and without the knowled...
# 5     A shy senior and a down-to-earth junior fall i...
# 6     In California, the former Navy SEAL Chon and h...
# 7     Meet the Borgens. William Borgens is an acclai...
# 8     In 1874, in the Imperial Russia, the aristocra...
# 9     In the 1960s, Richard Kuklinski is working as ...
# 10    The sunrise blinds the early risers of the cit...
# 11    A mysterious traveler infiltrates a dangerous ...
# 12    In both its story on and off the screen, 'Flan...
# 13    Hailey is in an unhappy marriage but she devel...
# 14    Yannick has to deal with the haunting by himse...
# 15    Seduced by the haunting beauty of a remote mar...
# ...

# %%
df_data.shape
# Out:
# (3389, 9)

# %%
df_geners_action = df_data.loc[(df_data['Genre'] == "Action")]

# %%
df_geners_action.shape
# Out:
# (41, 9)

# %%
df_genre_romance = df_data.loc[(df_data['Genre'].str.contains("Romance"))]

# %%
df_genre_romance.shape
# Out:
# (589, 9)

# %%
df_data.count(axis = 0)
# Out:
# Plot          3389
# Title         3389
# imdbVotes     3334
# Poster        1836
# imdbRating    3388
# Genre         3389
# imdbID        3389
# Year          3389
# Language      3389
# dtype: int64

# %%
b = []
a = [x.split(', ') for x in df_data.Genre.unique()]
a
# Out:
# [['Action', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Drama'],
#  ['Drama', 'Horror'],
#  ['Horror'],
#  ['Drama', 'Mystery'],
#  ['Drama', 'Thriller'],
#  ['Crime', 'Mystery', 'Thriller'],
#  ['Fantasy', 'Horror'],
#  ['Drama', 'Family'],
#  ['Animation'],
#  ['Drama', 'War'],
#  ['Comedy', 'Musical', 'Romance'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Comedy'],
#  ['Comedy', 'Crime'],
#  ['Action', 'Comedy', 'Romance'],
#  ['Action', 'Comedy'],
#  ['Crime'],
#  ['Fantasy'],
#  ['Action', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Crime', 'Drama'],
#  ['Drama', 'History'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Drama', 'Fantasy'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Fantasy'],
#  ['Drama', 'Thriller', 'War'],
#  ['Drama', 'Sport'],
# ...

# %%
a = {}
for index, row in df_data.iterrows(): 
    genres = row['Genre'].split(', ')
    for genre in  genres:
        if genre not in a:
            a[genre] = 0
        a[genre] += 1

# %%
print(a.keys())
# Out:
# dict_keys(['Action', 'Thriller', 'Drama', 'Romance', 'Comedy', 'Crime', 'Biography', 'Horror', 'Mystery', 'Fantasy', 'Family', 'Animation', 'War', 'Musical', 'Adventure', 'History', 'Sport', 'Sci-Fi', 'Music', 'Western'])

# %%
genre_list = []
for key, value in a.items():
    genre_list.append({'genre':key, 'count': value})
print(genre_list)
# Out:
# [{'genre': 'Action', 'count': 355}, {'genre': 'Thriller', 'count': 510}, {'genre': 'Drama', 'count': 2169}, {'genre': 'Romance', 'count': 589}, {'genre': 'Comedy', 'count': 1246}, {'genre': 'Crime', 'count': 364}, {'genre': 'Biography', 'count': 53}, {'genre': 'Horror', 'count': 259}, {'genre': 'Mystery', 'count': 224}, {'genre': 'Fantasy', 'count': 99}, {'genre': 'Family', 'count': 245}, {'genre': 'Animation', 'count': 13}, {'genre': 'War', 'count': 31}, {'genre': 'Musical', 'count': 125}, {'genre': 'Adventure', 'count': 128}, {'genre': 'History', 'count': 62}, {'genre': 'Sport', 'count': 57}, {'genre': 'Sci-Fi', 'count': 40}, {'genre': 'Music', 'count': 31}, {'genre': 'Western', 'count': 2}]

# %%
df_genre = pd.DataFrame(genre_list).set_index('genre')

# %%
df_genre
# Out:
#            count
# genre
# Action       355
# Thriller     510
# Drama       2169
# Romance      589
# Comedy      1246
# Crime        364
# Biography     53
# Horror       259
# Mystery      224
# Fantasy       99
# Family       245
# Animation     13
# War           31
# Musical      125
# Adventure    128
# History       62
# Sport         57
# Sci-Fi        40
# Music         31
# Western        2

# %%
df_genre = df_genre.sort_values('genre', ascending = True)

# %%
df_genre
# Out:
#            count
# genre
# Action       355
# Adventure    128
# Animation     13
# Biography     53
# Comedy      1246
# Crime        364
# Drama       2169
# Family       245
# Fantasy       99
# History       62
# Horror       259
# Music         31
# Musical      125
# Mystery      224
# Romance      589
# Sci-Fi        40
# Sport         57
# Thriller     510
# War           31
# Western        2

# %%
df_data = df_data.astype(object)

# %%
df_data["imdbVotes"] = df_data["imdbVotes"].str.replace(',', '')
df_data["imdbVotes"] = df_data["imdbVotes"].str.replace('-', '')
df_data['imdbVotes'].fillna('0')
df_data["imdbVotes"] = pd.to_numeric(df_data["imdbVotes"])

# %%
df_data["imdbRating"] = df_data["imdbRating"].str.replace('-', '')
df_data['imdbRating'].fillna('0')

df_data["imdbRating"] = pd.to_numeric(df_data['imdbRating']).astype(float)
df_data["imdbRating"]
# Out:
# 0       75.0
# 1       71.0
# 2       51.0
# 3       68.0
# 4       68.0
# 5       60.0
# 6       55.0
# 7       63.0
# 8       56.0
# 9       59.0
# 10      87.0
# 11      87.0
# 12      87.0
# 13      87.0
# 14      87.0
# 15      87.0
# 16      87.0
# 17      87.0
# 18      52.0
# 19      87.0
# 20      87.0
# 21      87.0
# 22      87.0
# 23      87.0
# 24      68.0
# 25      53.0
# 26      87.0
# 27      61.0
# 28      87.0
# 29      87.0
#         ...
# 3359     6.3
# 3360     6.7
# 3361     7.2
# 3362     6.9
# 3363     5.6
# 3364     7.4
# 3365     6.7
# 3366     5.8
# 3367     2.9
# 3368     5.1
# 3369     4.2
# 3370     7.5
# 3371     7.8
# 3372     7.6
# 3373     6.9
# 3374     8.0
# 3375     6.0
# 3376     5.8
# 3377     8.1
# 3378     7.3
# 3379     7.5
# 3380     3.5
# 3381     8.1
# 3382     7.5
# 3383     7.1
# 3384     7.5
# 3385     4.5
# 3386     7.3
# 3387     7.9
# 3388     4.6
# Name: imdbRating, Length: 3389, dtype: float64

# %%
df_data['new_var'] = df_data['imdbVotes'] - df_data['imdbRating']

# %%
df_data['new_var'] = df_data['new_var'] * df_data['new_var']

# %%
df_data['new_var']
# Out:
# 0        6780816.00
# 1        1437601.00
# 2        6395841.00
# 3        3024121.00
# 4        3097600.00
# 5        2184484.00
# 6        6906384.00
# 7        3129361.00
# 8        4153444.00
# 9        3240000.00
# 10       6922161.00
# 11       6922161.00
# 12       6922161.00
# 13       6922161.00
# 14       6922161.00
# 15       6922161.00
# 16       6922161.00
# 17       6922161.00
# 18       2890000.00
# 19       6922161.00
# 20       6922161.00
# 21       6922161.00
# 22       6922161.00
# 23       6922161.00
# 24       1094116.00
# 25       5058001.00
# 26       6922161.00
# 27       5740816.00
# 28       6922161.00
# 29       6922161.00
#            ...
# 3359            NaN
# 3360            NaN
# 3361      394132.84
# 3362       40040.01
# 3363      419126.76
# 3364        3672.36
# 3365      217435.69
# 3366            NaN
# 3367            NaN
# 3368            NaN
# 3369        2007.04
# 3370      189660.25
# 3371            NaN
# 3372      728291.56
# ...

# %%
df_data
# Out:
#                                                    Plot  \
# 0     Despite his tarnished reputation after the eve...
# 1     Based on the novel written by Stephen Chbosky,...
# 2     Mike Lane is a thirty-year old living in Tampa...
# 3     When Bond's latest assignment goes gravely wro...
# 4     Against medical advice and without the knowled...
# 5     A shy senior and a down-to-earth junior fall i...
# 6     In California, the former Navy SEAL Chon and h...
# 7     Meet the Borgens. William Borgens is an acclai...
# 8     In 1874, in the Imperial Russia, the aristocra...
# 9     In the 1960s, Richard Kuklinski is working as ...
# 10    The sunrise blinds the early risers of the cit...
# 11    A mysterious traveler infiltrates a dangerous ...
# 12    In both its story on and off the screen, 'Flan...
# 13    Hailey is in an unhappy marriage but she devel...
# 14    Yannick has to deal with the haunting by himse...
# 15    Seduced by the haunting beauty of a remote mar...
# ...
